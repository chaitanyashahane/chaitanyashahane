# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import math
import pandas as pd
import seaborn as sns
sns.set(color_codes=True) # adds a nice background to the graphs
# %matplotlib inline

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# # Reading data

# %%
#read csv
bs_df = pd.read_csv('Basketball.csv')

# %%
#Check datafram with head and tail
bs_df.head()
# Out:
#      Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0  Team 1          86  4385        2762     1647        552       563
# 1  Team 2          86  4262        2762     1581        573       608
# 2  Team 3          80  3442        2614     1241        598       775
# 3  Team 4          82  3386        2664     1187        616       861
# 4  Team 5          86  3368        2762     1209        633       920
#
#   BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 0         5947        3140                 33        23       1929
# 1         5900        3114                 25        25       1929
# 2         4534        3309                 10         8       1929
# 3         4398        3469                  6         6   1931to32
# 4         4631        3700                  8         7       1929
#
#    HighestPositionHeld
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
#Check data types, column names and Non null values
bs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     object
#  3   PlayedGames          61 non-null     object
#  4   WonGames             61 non-null     object
#  5   DrawnGames           61 non-null     object
#  6   LostGames            61 non-null     object
#  7   BasketScored         61 non-null     object
#  8   BasketGiven          61 non-null     object
#  9   TournamentChampion   61 non-null     object
#  10  Runner-up            61 non-null     object
#  11  TeamLaunch           61 non-null     object
#  12  HighestPositionHeld  61 non-null     int64
# dtypes: int64(2), object(11)
# memory usage: 6.3+ KB

# %% [markdown]
# # Cleaning Data

# %%
#Check for null values 
bs_df.isnull().sum()
# Out:
# Team                   0
# Tournament             0
# Score                  0
# PlayedGames            0
# WonGames               0
# DrawnGames             0
# LostGames              0
# BasketScored           0
# BasketGiven            0
# TournamentChampion     0
# Runner-up              0
# TeamLaunch             0
# HighestPositionHeld    0
# dtype: int64

# %%
#From the data few columns can be of data type int for easier analysis
pd.to_numeric(bs_df['Score'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "-"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-d249b639893f> in <module>
#       1 #From the data few columns can be of data type int for easier analysis
# ----> 2 pd.to_numeric(bs_df['Score'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     182         try:
#     183             values, _ = lib.maybe_convert_numeric(
# --> 184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#     186         except (ValueError, TypeError):
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "-" at position 60

# %%
#Looks like we have '-' values instead of null values, replace it with 0
df=bs_df.replace('-','0')

# %%
df.tail()
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 56  Team 57           1    34          38        8         10        20
# 57  Team 58           1    22          30        7          8        15
# 58  Team 59           1    19          30        7          5        18
# 59  Team 60           1    14          30        5          4        21
# 60  Team 61           1     0           0        0          0         0
#
#    BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 56           38          66                  0         0    2009-10
# 57           37          57                  0         0    1956-57
# 58           51          85                  0         0    1951~52
# 59           34          65                  0         0    1955-56
# 60            0           0                  0         0    2017~18
#
#     HighestPositionHeld
# 56                   20
# 57                   16
# 58                   16
# 59                   15
# 60                    9

# %%
#get subset of df where score is not 0 (when score is 0, team has no record to analyze hence out of contention)
mydf = df[df['PlayedGames'] != '0']
#TeamLaunch year can be cleaned more to be an useful data
mydf['LaunchYear'] = mydf.TeamLaunch.apply(lambda x: x[0:4])

# %%
mydf.count()
# Out:
# Team                   61
# Tournament             61
# Score                  61
# PlayedGames            61
# WonGames               61
# DrawnGames             61
# LostGames              61
# BasketScored           61
# BasketGiven            61
# TournamentChampion     61
# Runner-up              61
# TeamLaunch             61
# HighestPositionHeld    61
# LaunchYear             61
# dtype: int64

# %%
#change column data types to int where possible and required
mydf['Score'] =mydf['Score'].astype(str).astype(int)
mydf['PlayedGames'] =mydf['PlayedGames'].astype(str).astype(int)
mydf['WonGames'] =mydf['WonGames'].astype(str).astype(int)
mydf['LostGames'] =mydf['LostGames'].astype(str).astype(int)
mydf['DrawnGames'] =mydf['DrawnGames'].astype(str).astype(int)
mydf['BasketScored'] =mydf['BasketScored'].astype(str).astype(int)
mydf['BasketGiven'] =mydf['BasketGiven'].astype(str).astype(int)
mydf['TournamentChampion'] =mydf['TournamentChampion'].astype(str).astype(int)
mydf['Runner-up'] =mydf['Runner-up'].astype(str).astype(int)
mydf['LaunchYear'] =mydf['LaunchYear'].astype(str).astype(int)

# %%
mydf.columns
# Out:
# Index(['Team', 'Tournament', 'Score', 'PlayedGames', 'WonGames', 'DrawnGames',
#        'LostGames', 'BasketScored', 'BasketGiven', 'TournamentChampion',
#        'Runner-up', 'TeamLaunch', 'HighestPositionHeld', 'LaunchYear'],
#       dtype='object')

# %%
cols=['Tournament', 'Score', 'PlayedGames', 'WonGames', 'DrawnGames',
       'LostGames', 'BasketScored', 'BasketGiven', 'TournamentChampion',
       'Runner-up']

# %%
mydf[cols] = mydf[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
mydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 0 to 60
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     int64
#  3   PlayedGames          61 non-null     int64
#  4   WonGames             61 non-null     int64
#  5   DrawnGames           61 non-null     int64
#  6   LostGames            61 non-null     int64
#  7   BasketScored         61 non-null     int64
#  8   BasketGiven          61 non-null     int64
#  9   TournamentChampion   61 non-null     int64
#  10  Runner-up            61 non-null     int64
#  11  TeamLaunch           61 non-null     object
#  12  HighestPositionHeld  61 non-null     int64
#  13  LaunchYear           61 non-null     int64
# dtypes: int64(12), object(2)
# memory usage: 7.1+ KB

# %%
mydf.replace(np.nan, 0, inplace=True)

# %%
#team names for easy visualization
mydf['TeamName'] = mydf.Team.apply(lambda x: x[4:len(x)])

# %% [markdown]
# # Perform EDA

# %% [markdown]
# # 1. Univariant EDA

# %%
#Find winning % of each team
wonPercentage = (mydf['WonGames']/mydf['PlayedGames'])*100
mydf['WinPercentage'] = wonPercentage

# %%
#defence record of each team
defence = mydf['BasketGiven']/mydf['PlayedGames']
mydf['defenceFactor'] = defence

# %%
mydf.describe()
# Out:
#        Tournament        Score  PlayedGames     WonGames  DrawnGames  \
# count   61.000000    61.000000    61.000000    61.000000   61.000000
# mean    24.000000   901.426230   796.819672   303.967213  188.934426
# std     26.827225  1134.899121   876.282765   406.991030  201.799477
# min      1.000000     0.000000     0.000000     0.000000    0.000000
# 25%      4.000000    96.000000   114.000000    34.000000   24.000000
# 50%     12.000000   375.000000   423.000000   123.000000   95.000000
# 75%     38.000000  1351.000000  1318.000000   426.000000  330.000000
# max     86.000000  4385.000000  2762.000000  1647.000000  633.000000
#
#          LostGames  BasketScored  BasketGiven  TournamentChampion  Runner-up  \
# count    61.000000     61.000000    61.000000           61.000000  61.000000
# mean    303.754098   1140.344262  1140.229508            1.426230   1.409836
# std     294.708594   1506.740211  1163.710766            5.472535   4.540107
# min       0.000000      0.000000     0.000000            0.000000   0.000000
# 25%      62.000000    153.000000   221.000000            0.000000   0.000000
# 50%     197.000000    430.000000   632.000000            0.000000   0.000000
# 75%     563.000000   1642.000000  1951.000000            0.000000   0.000000
# max    1070.000000   5947.000000  3889.000000           33.000000  25.000000
#
#        HighestPositionHeld   LaunchYear  WinPercentage  defenceFactor
# count            61.000000    61.000000      60.000000      60.000000
# mean              7.081967  1958.918033      31.364790       1.632580
# std               5.276663    27.484114       7.831199       0.383277
# min               1.000000  1929.000000      16.666667       1.127444
# 25%               3.000000  1935.000000      27.607494       1.411166
# 50%               6.000000  1951.000000      30.491722       1.512947
# 75%              10.000000  1978.000000      33.540164       1.676516
# max              20.000000  2017.000000      59.630702       2.833333

# %%
df_wongames= mydf.nlargest(20, ['WonGames'])

# %%
sns.barplot(y=df_wongames['Team'], x= df_wongames['WonGames'])
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 3, 1)
plt.title('Tournament')
sns.histplot(mydf['Tournament'],color='green')

# subplot 2
plt.subplot(1, 3, 2)
plt.title('Score')
sns.histplot(mydf['Score'],color='blue')

# subplot 3l
plt.subplot(1, 3, 3)
plt.title('PlayedGames')
sns.histplot(mydf['PlayedGames'],color='red')


plt.figure(figsize=(20,6))
plt.subplot(1, 3, 1)
plt.title('Tournament')
sns.boxplot(mydf['Tournament'],orient='vertical',color='green')

# subplot 2
plt.subplot(1, 3, 2)
plt.title('Score')
sns.boxplot(mydf['Score'],orient='vertical',color='blue')

# subplot 3
plt.subplot(1, 3, 3)
plt.title('PlayedGames')
sns.boxplot(mydf['PlayedGames'],orient='vertical',color='red')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# ### From above analysis about number of tournaments played, score and gamesplayed, it can be deduced than top teams in the data(i.e. Team 1,Team 2, Team 3, etc.) are the teams who have played most tournaments, scored the most and played more games than other teams. Scores have few outliers above upper fence, they are mostly the top teams.

# %%
plt.figure(figsize=(20,6))
plt.subplot(2, 3, 1)
plt.title('WonGames')
sns.distplot(mydf['WonGames'],color='green')

# subplot 2
plt.subplot(2, 3, 2)
plt.title('LostGames')
sns.distplot(mydf['LostGames'],color='blue')

# subplot 3
plt.subplot(2, 3, 3)
plt.title('BasketScored')
sns.distplot(mydf['BasketScored'],color='red')

plt.figure(figsize=(20,6))
plt.subplot(1, 3, 1)
plt.title('WonGames')
sns.boxplot(mydf['WonGames'],orient='vertical',color='green')

# subplot 2
plt.subplot(1, 3, 2)
plt.title('LostGames')
sns.boxplot(mydf['LostGames'],orient='vertical',color='blue')

# subplot 3
plt.subplot(1, 3, 3)
plt.title('BasketScored')
sns.boxplot(mydf['BasketScored'],orient='vertical',color='red')

plt.show()
# Out:
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\python\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# c:\python\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\python\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# c:\python\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\python\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# ### From previous analysis, we know that top teams who have played the most games. Therefore, its fair to say and from this analysis too, that top teams have won more games, lost more games and have scored most baskets. WonGames and BasketScored have few outliers. Similarly like before, top team must be these outliers as they are on top they won and scored more.

# %%
# subplot 3
plt.figure(figsize=(20,6))
plt.subplot(3, 3, 1)
plt.title('BasketGiven')
sns.distplot(mydf['BasketGiven'],color='green')

# subplot 3
plt.subplot(3, 3, 2)
plt.title('TournamentChampion')
sns.distplot(mydf['TournamentChampion'],color='blue')

# subplot 3
plt.subplot(3, 3, 3)
plt.title('Runner-up')
sns.distplot(mydf['Runner-up'],color='red')

plt.figure(figsize=(20,6))
plt.subplot(1, 3, 1)
plt.title('BasketGiven')
sns.boxplot(mydf['BasketGiven'],orient='vertical',color='green')

# subplot 2
plt.subplot(1, 3, 2)
plt.title('TournamentChampion')
sns.boxplot(mydf['TournamentChampion'],orient='vertical',color='blue')

# subplot 3
plt.subplot(1, 3, 3)
plt.title('Runner-up')
sns.boxplot(mydf['Runner-up'],orient='vertical',color='red')


plt.show()
# Out:
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\python\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# c:\python\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\python\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# c:\python\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\python\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# ###  From previous analysis, we know that top teams who have played the most games. Therefore, its fair to say and from this analysis too we can say that top teams have played more games. therefore given more baskets and been to more finals than other teams. There are only few teans who have reached finals and most of them are at the top and those we can see as outliers.

# %%
# subplot 3
plt.figure(figsize=(20,6))
# subplot 3
plt.subplot(1, 2, 1)
plt.title('WinPercentage')
sns.distplot(mydf['WinPercentage'],color='blue')

# subplot 3
plt.subplot(1, 2, 2)
plt.title('defenceFactor')
sns.distplot(mydf['defenceFactor'],color='red')

plt.figure(figsize=(20,6))
# subplot 2
plt.subplot(1, 2, 1)
plt.title('WinPercentage')
sns.boxplot(mydf['WinPercentage'],orient='vertical',color='blue')

# subplot 3
plt.subplot(1, 2, 2)
plt.title('defenceFactor')
sns.boxplot(mydf['defenceFactor'],orient='vertical',color='red')

plt.show()
# Out:
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\python\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# c:\python\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\python\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# ### Win% and defence factor are 2 important data driven column deduced. It say about the winning % of teams(wongames/playedgames) and defence factor(baskets given every game). Teams with more win % and less defence factor. So outliers above upper fence for defence factor are not good with defence and outliers for win % either suggest they are very good at winning(upper fence outliers) or they are losing more than winning(lower fence outliers).

# %%
#teams perform

plt.figure(figsize=(20,6))
plt.subplot(1, 2, 1)
plt.title('HighestPositionHeld')
sns.distplot(mydf['HighestPositionHeld'],color='red')


plt.figure(figsize=(20,6))
plt.subplot(1, 2, 2)
plt.title('HighestPositionHeld')
sns.boxplot(mydf['HighestPositionHeld'],orient='vertical',color='green')

plt.show()
# Out:
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\python\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# ###  This analysis suggests how many teams performed well in atleast one tournament to read top positions

# %%
sns.lineplot('Team', 'WonGames', data=df_wongames.head(10), color='red')
sns.lineplot('Team', 'BasketScored', data=df_wongames.head(10), color='green')
sns.lineplot('Team', 'BasketGiven', data=df_wongames.head(10), color='orange')
sns.lineplot('Team', 'Score', data=df_wongames.head(10), color='black')
plt.grid()
plt.xticks(rotation=90)
plt.legend(labels=['games won', 'baskets scored', 'baskets given', 'score'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # 2.  Bivariate Analysis

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = mydf.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col0,#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col2,#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col1,#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col3,#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col6,#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col0,#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col2,#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col4,#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col1,#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col3,#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col6,#T_875515a2_7456_11eb_a41f_9061ae83ef86row4_col2,#T_875515a2_7456_11eb_a41f_9061ae83ef86row4_col4,#T_875515a2_7456_11eb_a41f_9061ae83ef86row5_col5,#T_875515a2_7456_11eb_a41f_9061ae83ef86row6_col1,#T_875515a2_7456_11eb_a41f_9061ae83ef86row6_col3,#T_875515a2_7456_11eb_a41f_9061ae83ef86row6_col6,#T_875515a2_7456_11eb_a41f_9061ae83ef86row7_col7,#T_875515a2_7456_11eb_a41f_9061ae83ef86row8_col8,#T_875515a2_7456_11eb_a41f_9061ae83ef86row9_col9,#T_875515a2_7456_11eb_a41f_9061ae83ef86row10_col10,#T_875515a2_7456_11eb_a41f_9061ae83ef86row11_col11,#T_875515a2_7456_11eb_a41f_9061ae83ef86row12_col12,#T_875515a2_7456_11eb_a41f_9061ae83ef86row13_col13{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col1,#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col0,#T_875515a2_7456_11eb_a41f_9061ae83ef86row5_col7,#T_875515a2_7456_11eb_a41f_9061ae83ef86row7_col5{
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col3,#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col6,#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col0,#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col2,#T_875515a2_7456_11eb_a41f_9061ae83ef86row4_col5,#T_875515a2_7456_11eb_a41f_9061ae83ef86row5_col4,#T_875515a2_7456_11eb_a41f_9061ae83ef86row6_col2{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col4,#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col7,#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col7,#T_875515a2_7456_11eb_a41f_9061ae83ef86row4_col0,#T_875515a2_7456_11eb_a41f_9061ae83ef86row4_col7,#T_875515a2_7456_11eb_a41f_9061ae83ef86row7_col0,#T_875515a2_7456_11eb_a41f_9061ae83ef86row7_col2,#T_875515a2_7456_11eb_a41f_9061ae83ef86row7_col4{
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col5,#T_875515a2_7456_11eb_a41f_9061ae83ef86row5_col0{
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col6,#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col2,#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col1,#T_875515a2_7456_11eb_a41f_9061ae83ef86row6_col0{
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col8{
#             background-color:  #f7b194;
#             color:  #000000;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col9{
#             background-color:  #f59d7e;
#             color:  #000000;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col10,#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col11{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col11,#T_875515a2_7456_11eb_a41f_9061ae83ef86row5_col10,#T_875515a2_7456_11eb_a41f_9061ae83ef86row7_col10{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col12{
#             background-color:  #d75445;
#             color:  #000000;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row0_col13,#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col13,#T_875515a2_7456_11eb_a41f_9061ae83ef86row13_col9{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col4,#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col5,#T_875515a2_7456_11eb_a41f_9061ae83ef86row4_col1,#T_875515a2_7456_11eb_a41f_9061ae83ef86row5_col2{
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col5,#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col12,#T_875515a2_7456_11eb_a41f_9061ae83ef86row6_col12,#T_875515a2_7456_11eb_a41f_9061ae83ef86row12_col3{
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col7,#T_875515a2_7456_11eb_a41f_9061ae83ef86row4_col6,#T_875515a2_7456_11eb_a41f_9061ae83ef86row6_col4,#T_875515a2_7456_11eb_a41f_9061ae83ef86row7_col1{
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col8{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col9{
#             background-color:  #e9785d;
#             color:  #000000;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col10,#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col11{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col11,#T_875515a2_7456_11eb_a41f_9061ae83ef86row12_col13{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col12,#T_875515a2_7456_11eb_a41f_9061ae83ef86row5_col1,#T_875515a2_7456_11eb_a41f_9061ae83ef86row12_col1,#T_875515a2_7456_11eb_a41f_9061ae83ef86row12_col6{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row1_col13,#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col13,#T_875515a2_7456_11eb_a41f_9061ae83ef86row4_col10,#T_875515a2_7456_11eb_a41f_9061ae83ef86row5_col11{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col3,#T_875515a2_7456_11eb_a41f_9061ae83ef86row8_col9,#T_875515a2_7456_11eb_a41f_9061ae83ef86row9_col8{
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col8{
#             background-color:  #f7b599;
#             color:  #000000;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col9,#T_875515a2_7456_11eb_a41f_9061ae83ef86row9_col7{
#             background-color:  #f6a283;
#             color:  #000000;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col10,#T_875515a2_7456_11eb_a41f_9061ae83ef86row11_col8{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row2_col12,#T_875515a2_7456_11eb_a41f_9061ae83ef86row12_col0,#T_875515a2_7456_11eb_a41f_9061ae83ef86row12_col2{
#             background-color:  #d85646;
#             color:  #000000;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col4,#T_875515a2_7456_11eb_a41f_9061ae83ef86row4_col3{
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col5,#T_875515a2_7456_11eb_a41f_9061ae83ef86row5_col6{
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col7,#T_875515a2_7456_11eb_a41f_9061ae83ef86row7_col3{
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col8{
#             background-color:  #ec7f63;
#             color:  #000000;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col9,#T_875515a2_7456_11eb_a41f_9061ae83ef86row8_col3{
#             background-color:  #e36c55;
#             color:  #000000;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row3_col10,#T_875515a2_7456_11eb_a41f_9061ae83ef86row6_col10{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_875515a2_7456_11eb_a41f_9061ae83ef86row4_col8{
#             background-color:  #f4c6af;
#             color:  #0000

# %% [markdown]
# ### Like we saw earlier, Tournament, score, playedgames, wongame, drawngames, lostgames, basketscored, basketgiven, tournamentchampion, runner-up and win percentage are correlated.

# %% [markdown]
# # 3. Multivariate Regression and Scatter Plot

# %%
plt.figure(figsize=(20,6))
sns.pairplot(mydf, y_vars='Tournament', x_vars=["Score", "PlayedGames",'WonGames', 'LostGames','BasketScored','BasketGiven','TournamentChampion','Runner-up','WinPercentage'
                                                        ])
plt.show()

# %% [markdown]
# ### Like all the above analysis suggest, more tournaments you play more you score, more you won games, more games to lose, more basket score or give, more chances to be in the final

# %%
#team that won championships most times
mydf.loc[mydf['TournamentChampion'].idxmax()]
# Out:
# Team                   Team 1
# Tournament                 86
# Score                    4385
# PlayedGames              2762
# WonGames                 1647
# DrawnGames                552
# LostGames                 563
# BasketScored             5947
# BasketGiven              3140
# TournamentChampion         33
# Runner-up                  23
# TeamLaunch               1929
# HighestPositionHeld         1
# TeamName                    1
# Name: 0, dtype: object

# %%
#team that scored most times
mydf.loc[mydf['Score'].idxmax()]
# Out:
# Team                   Team 1
# Tournament                 86
# Score                    4385
# PlayedGames              2762
# WonGames                 1647
# DrawnGames                552
# LostGames                 563
# BasketScored             5947
# BasketGiven              3140
# TournamentChampion         33
# Runner-up                  23
# TeamLaunch               1929
# HighestPositionHeld         1
# TeamName                    1
# Name: 0, dtype: object

# %%
#team that won most of the games
mydf.loc[mydf['WonGames'].idxmax()]
# Out:
# Team                   Team 1
# Tournament                 86
# Score                    4385
# PlayedGames              2762
# WonGames                 1647
# DrawnGames                552
# LostGames                 563
# BasketScored             5947
# BasketGiven              3140
# TournamentChampion         33
# Runner-up                  23
# TeamLaunch               1929
# HighestPositionHeld         1
# TeamName                    1
# Name: 0, dtype: object

# %%
#team that scored most baskets
mydf.loc[mydf['BasketScored'].idxmax()]
# Out:
# Team                   Team 1
# Tournament                 86
# Score                    4385
# PlayedGames              2762
# WonGames                 1647
# DrawnGames                552
# LostGames                 563
# BasketScored             5947
# BasketGiven              3140
# TournamentChampion         33
# Runner-up                  23
# TeamLaunch               1929
# HighestPositionHeld         1
# TeamName                    1
# Name: 0, dtype: object

# %%
#team that lost most of the finals
mydf.loc[mydf['Runner-up'].idxmax()]
# Out:
# Team                   Team 2
# Tournament                 86
# Score                    4262
# PlayedGames              2762
# WonGames                 1581
# DrawnGames                573
# LostGames                 608
# BasketScored             5900
# BasketGiven              3114
# TournamentChampion         25
# Runner-up                  25
# TeamLaunch               1929
# HighestPositionHeld         1
# TeamName                    2
# Name: 1, dtype: object

# %%
mydf.sort_values(by=['WinPercentage'], ascending=False).head(10)
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0    Team 1          86   4385         2762      1647         552        563
# 1    Team 2          86   4262         2762      1581         573        608
# 2    Team 3          80   3442         2614      1241         598        775
# 3    Team 4          82   3386         2664      1187         616        861
# 4    Team 5          86   3368         2762      1209         633        920
# 20  Team 21          17    970          646       266         172        208
# 5    Team 6          73   2819         2408       990         531        887
# 7    Team 8          70   2573         2302       864         577        861
# 10  Team 11          45   1814         1530       563         392        575
# 6    Team 7          82   2792         2626       948         608       1070
#
#     BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0           5947         3140                  33         23        1929
# 1           5900         3114                  25         25        1929
# 2           4534         3309                  10          8        1929
# 3           4398         3469                   6          6        1931
# 4           4631         3700                   8          7        1929
# 20           892          789                   0          1        1998
# 5           3680         3373                   1          4        1934
# 7           3228         3230                   2          3        1929
# 10          2052         2188                   1          5        1941
# 6           3609         3889                   0          0        1929
#
#     HighestPositionHeld TeamName  WinPercentage
# 0                     1        1      59.630702
# 1                     1        2      57.241130
# 2                     1        3      47.475134
# 3                     1        4      44.557057
# 4                     1        5      43.772629
# 20                    2       21      41.176471
# 5                     1        6      41.112957
# 7                     1        8      37.532580
# 10                    1       11      36.797386
# 6                     3        7      36.100533

# %%
#team with highest winning %
mydf.loc[mydf['WinPercentage'].idxmax()]
# Out:
# Team                    Team 1
# Tournament                  86
# Score                     4385
# PlayedGames               2762
# WonGames                  1647
# DrawnGames                 552
# LostGames                  563
# BasketScored              5947
# BasketGiven               3140
# TournamentChampion          33
# Runner-up                   23
# TeamLaunch                1929
# HighestPositionHeld          1
# TeamName                     1
# WinPercentage          59.6307
# Name: 0, dtype: object

# %%
#defence record of each team
defence = mydf['BasketGiven']/mydf['PlayedGames']
mydf['defenceFactor'] = defence
# Out:
# c:\python\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#team with best defence record
mydf[mydf['defenceFactor']==mydf['defenceFactor'].min()]
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 1  Team 2          86   4262         2762      1581         573        608
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 1          5900         3114                  25         25        1929
#
#    HighestPositionHeld TeamName  WinPercentage  defenceFactor
# 1                    1        2       57.24113       1.127444

# %%
mydf.sort_values(by=['defenceFactor']).head(10)
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 1    Team 2          86   4262         2762      1581         573        608
# 0    Team 1          86   4385         2762      1647         552        563
# 45  Team 46           3     96          114        26          44         44
# 20  Team 21          17    970          646       266         172        208
# 41  Team 42           6    150          180        53          44         83
# 2    Team 3          80   3442         2614      1241         598        775
# 3    Team 4          82   3386         2664      1187         616        861
# 4    Team 5          86   3368         2762      1209         633        920
# 30  Team 31          12    375          423       123         102        198
# 18  Team 19          27   1148          988       333         256        399
#
#     BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 1           5900         3114                  25         25        1929
# 0           5947         3140                  33         23        1929
# 45           101          139                   0          0        1990
# 20           892          789                   0          1        1998
# 41           165          221                   0          0        1963
# 2           4534         3309                  10          8        1929
# 3           4398         3469                   6          6        1931
# 4           4631         3700                   8          7        1929
# 30           422          581                   0          0        1974
# 18          1182         1371                   0          0        1960
#
#     HighestPositionHeld TeamName  WinPercentage  defenceFactor
# 1                     1        2      57.241130       1.127444
# 0                     1        1      59.630702       1.136857
# 45                    9       46      22.807018       1.219298
# 20                    2       21      41.176471       1.221362
# 41                    7       42      29.444444       1.227778
# 2                     1        3      47.475134       1.265876
# 3                     1        4      44.557057       1.302177
# 4                     1        5      43.772629       1.339609
# 30                    7       31      29.078014       1.373522
# 18                    3       19      33.704453       1.387652

# %% [markdown]
# ### As expected top teams have good defence record but teams like Team 20, Team 46, Team 42 have good defence but 42 and 46 haven't played much. Team 20 looks new and have played enough. Team 20 is also have good winning %.

# %%
g = sns.swarmplot(mydf['TeamName'], mydf['TeamLaunch']);
# Out:
# c:\python\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
mydf.sort_values(by=['Tournament'], ascending=False).head(10)
# Out:
#       Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0   Team 1          86   4385         2762      1647         552        563
# 4   Team 5          86   3368         2762      1209         633        920
# 1   Team 2          86   4262         2762      1581         573        608
# 3   Team 4          82   3386         2664      1187         616        861
# 6   Team 7          82   2792         2626       948         608       1070
# 2   Team 3          80   3442         2614      1241         598        775
# 5   Team 6          73   2819         2408       990         531        887
# 7   Team 8          70   2573         2302       864         577        861
# 8   Team 9          58   2109         1986       698         522        766
# 9  Team 10          51   1884         1728       606         440        682
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
# 4          4631         3700                   8          7        1929
# 1          5900         3114                  25         25        1929
# 3          4398         3469                   6          6        1931
# 6          3609         3889                   0          0        1929
# 2          4534         3309                  10          8        1929
# 5          3680         3373                   1          4        1934
# 7          3228         3230                   2          3        1929
# 8          2683         2847                   0          1        1939
# 9          2159         2492                   1          0        1932
#
#    HighestPositionHeld TeamName  WinPercentage  defenceFactor
# 0                    1        1      59.630702       1.136857
# 4                    1        5      43.772629       1.339609
# 1                    1        2      57.241130       1.127444
# 3                    1        4      44.557057       1.302177
# 6                    3        7      36.100533       1.480960
# 2                    1        3      47.475134       1.265876
# 5                    1        6      41.112957       1.400748
# 7                    1        8      37.532580       1.403128
# 8                    2        9      35.146022       1.433535
# 9                    1       10      35.069444       1.442130

# %%
mydf.sort_values(by=['Score'], ascending=False).head(10)
# Out:
#       Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0   Team 1          86   4385         2762      1647         552        563
# 1   Team 2          86   4262         2762      1581         573        608
# 2   Team 3          80   3442         2614      1241         598        775
# 3   Team 4          82   3386         2664      1187         616        861
# 4   Team 5          86   3368         2762      1209         633        920
# 5   Team 6          73   2819         2408       990         531        887
# 6   Team 7          82   2792         2626       948         608       1070
# 7   Team 8          70   2573         2302       864         577        861
# 8   Team 9          58   2109         1986       698         522        766
# 9  Team 10          51   1884         1728       606         440        682
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
# 1          5900         3114                  25         25        1929
# 2          4534         3309                  10          8        1929
# 3          4398         3469                   6          6        1931
# 4          4631         3700                   8          7        1929
# 5          3680         3373                   1          4        1934
# 6          3609         3889                   0          0        1929
# 7          3228         3230                   2          3        1929
# 8          2683         2847                   0          1        1939
# 9          2159         2492                   1          0        1932
#
#    HighestPositionHeld TeamName  WinPercentage  defenceFactor
# 0                    1        1      59.630702       1.136857
# 1                    1        2      57.241130       1.127444
# 2                    1        3      47.475134       1.265876
# 3                    1        4      44.557057       1.302177
# 4                    1        5      43.772629       1.339609
# 5                    1        6      41.112957       1.400748
# 6                    3        7      36.100533       1.480960
# 7                    1        8      37.532580       1.403128
# 8                    2        9      35.146022       1.433535
# 9                    1       10      35.069444       1.442130

# %%
mydf.sort_values(by=['PlayedGames'], ascending=False).head(10)
# Out:
#       Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0   Team 1          86   4385         2762      1647         552        563
# 1   Team 2          86   4262         2762      1581         573        608
# 4   Team 5          86   3368         2762      1209         633        920
# 3   Team 4          82   3386         2664      1187         616        861
# 6   Team 7          82   2792         2626       948         608       1070
# 2   Team 3          80   3442         2614      1241         598        775
# 5   Team 6          73   2819         2408       990         531        887
# 7   Team 8          70   2573         2302       864         577        861
# 8   Team 9          58   2109         1986       698         522        766
# 9  Team 10          51   1884         1728       606         440        682
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
# 1          5900         3114                  25         25        1929
# 4          4631         3700                   8          7        1929
# 3          4398         3469                   6          6        1931
# 6          3609         3889                   0          0        1929
# 2          4534         3309                  10          8        1929
# 5          3680         3373                   1          4        1934
# 7          3228         3230                   2          3        1929
# 8          2683         2847                   0          1        1939
# 9          2159         2492                   1          0        1932
#
#    HighestPositionHeld TeamName  WinPercentage  defenceFactor
# 0                    1        1      59.630702       1.136857
# 1                    1        2      57.241130       1.127444
# 4                    1        5      43.772629       1.339609
# 3                    1        4      44.557057       1.302177
# 6                    3        7      36.100533       1.480960
# 2                    1        3      47.475134       1.265876
# 5                    1        6      41.112957       1.400748
# 7                    1        8      37.532580       1.403128
# 8                    2        9      35.146022       1.433535
# 9                    1       10      35.069444       1.442130

# %%
mydf.sort_values(by=['WonGames'], ascending=False).head(10)
# Out:
#       Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0   Team 1          86   4385         2762      1647         552        563
# 1   Team 2          86   4262         2762      1581         573        608
# 2   Team 3          80   3442         2614      1241         598        775
# 4   Team 5          86   3368         2762      1209         633        920
# 3   Team 4          82   3386         2664      1187         616        861
# 5   Team 6          73   2819         2408       990         531        887
# 6   Team 7          82   2792         2626       948         608       1070
# 7   Team 8          70   2573         2302       864         577        861
# 8   Team 9          58   2109         1986       698         522        766
# 9  Team 10          51   1884         1728       606         440        682
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
# 1          5900         3114                  25         25        1929
# 2          4534         3309                  10          8        1929
# 4          4631         3700                   8          7        1929
# 3          4398         3469                   6          6        1931
# 5          3680         3373                   1          4        1934
# 6          3609         3889                   0          0        1929
# 7          3228         3230                   2          3        1929
# 8          2683         2847                   0          1        1939
# 9          2159         2492                   1          0        1932
#
#    HighestPositionHeld TeamName  WinPercentage  defenceFactor
# 0                    1        1      59.630702       1.136857
# 1                    1        2      57.241130       1.127444
# 2                    1        3      47.475134       1.265876
# 4                    1        5      43.772629       1.339609
# 3                    1        4      44.557057       1.302177
# 5                    1        6      41.112957       1.400748
# 6                    3        7      36.100533       1.480960
# 7                    1        8      37.532580       1.403128
# 8                    2        9      35.146022       1.433535
# 9                    1       10      35.069444       1.442130

# %%
mydf.sort_values(by=['BasketScored'], ascending=False).head(10)
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0    Team 1          86   4385         2762      1647         552        563
# 1    Team 2          86   4262         2762      1581         573        608
# 4    Team 5          86   3368         2762      1209         633        920
# 2    Team 3          80   3442         2614      1241         598        775
# 3    Team 4          82   3386         2664      1187         616        861
# 5    Team 6          73   2819         2408       990         531        887
# 6    Team 7          82   2792         2626       948         608       1070
# 7    Team 8          70   2573         2302       864         577        861
# 8    Team 9          58   2109         1986       698         522        766
# 11  Team 12          51   1789         1698       586         389        723
#
#     BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0           5947         3140                  33         23        1929
# 1           5900         3114                  25         25        1929
# 4           4631         3700                   8          7        1929
# 2           4534         3309                  10          8        1929
# 3           4398         3469                   6          6        1931
# 5           3680         3373                   1          4        1934
# 6           3609         3889                   0          0        1929
# 7           3228         3230                   2          3        1929
# 8           2683         2847                   0          1        1939
# 11          2278         2624                   0          0        1939
#
#     HighestPositionHeld TeamName  WinPercentage  defenceFactor
# 0                     1        1      59.630702       1.136857
# 1                     1        2      57.241130       1.127444
# 4                     1        5      43.772629       1.339609
# 2                     1        3      47.475134       1.265876
# 3                     1        4      44.557057       1.302177
# 5                     1        6      41.112957       1.400748
# 6                     3        7      36.100533       1.480960
# 7                     1        8      37.532580       1.403128
# 8                     2        9      35.146022       1.433535
# 11                    4       12      34.511190       1.545347

# %%
#10 newst teams
newdf = mydf.sort_values(by=['TeamLaunch'], ascending=False).head(10)
newdf.sort_values(by=['WinPercentage'], ascending=False).head(10)
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 20  Team 21          17    970          646       266         172        208
# 38  Team 39           4    190          160        52          45         63
# 24  Team 25          12    553          456       147         112        197
# 43  Team 44           3    132          114        35          27         52
# 36  Team 37           6    242          228        62          56        110
# 47  Team 48           2     83           80        20          23         37
# 42  Team 43           4    148          152        37          37         78
# 48  Team 49           2     81           80        19          24         37
# 55  Team 56           1     35           38         8          11         19
# 56  Team 57           1     34           38         8          10         20
#
#     BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 20           892          789                   0          1        1998
# 38           199          241                   0          0        1994
# 24           520          633                   0          0        2004
# 43           139          167                   0          0        2014
# 36           244          366                   0          0        2007
# 47            62          117                   0          0        1996
# 42           155          253                   0          0        1999
# 48            70          115                   0          0        1995
# 55            36           55                   0          0        2016
# 56            38           66                   0          0        2009
#
#     HighestPositionHeld TeamName  WinPercentage  defenceFactor
# 20                    2       21      41.176471       1.221362
# 38                   10       39      32.500000       1.506250
# 24                    6       25      32.236842       1.388158
# 43                   10       44      30.701754       1.464912
# 36                    8       37      27.192982       1.605263
# 47                   17       48      25.000000       1.462500
# 42                   17       43      24.342105       1.664474
# 48                   19       49      23.750000       1.437500
# 55                   17       56      21.052632       1.447368
# 56                   20       57      21.052632       1.736842

# %% [markdown]
# ### These top 10 newest teams. It seems new teams have not reach the performing level as the oldest teams have. None of these teams have reached finals except Team 20. Team 20 is performing way better than other 9 teams. Win% of Team 20 are on very higher side

# %%
newdf.sort_values(by=['defenceFactor']).head(10)
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 20  Team 21          17    970          646       266         172        208
# 24  Team 25          12    553          456       147         112        197
# 48  Team 49           2     81           80        19          24         37
# 55  Team 56           1     35           38         8          11         19
# 47  Team 48           2     83           80        20          23         37
# 43  Team 44           3    132          114        35          27         52
# 38  Team 39           4    190          160        52          45         63
# 36  Team 37           6    242          228        62          56        110
# 42  Team 43           4    148          152        37          37         78
# 56  Team 57           1     34           38         8          10         20
#
#     BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 20           892          789                   0          1        1998
# 24           520          633                   0          0        2004
# 48            70          115                   0          0        1995
# 55            36           55                   0          0        2016
# 47            62          117                   0          0        1996
# 43           139          167                   0          0        2014
# 38           199          241                   0          0        1994
# 36           244          366                   0          0        2007
# 42           155          253                   0          0        1999
# 56            38           66                   0          0        2009
#
#     HighestPositionHeld TeamName  WinPercentage  defenceFactor
# 20                    2       21      41.176471       1.221362
# 24                    6       25      32.236842       1.388158
# 48                   19       49      23.750000       1.437500
# 55                   17       56      21.052632       1.447368
# 47                   17       48      25.000000       1.462500
# 43                   10       44      30.701754       1.464912
# 38                   10       39      32.500000       1.506250
# 36                    8       37      27.192982       1.605263
# 42                   17       43      24.342105       1.664474
# 56                   20       57      21.052632       1.736842

# %% [markdown]
# ### Defence factor of Team 20 is also the highest amongst the top 10 new teams and seems greates performing team amongst that group

# %%
#10 oldest teams
olddf = mydf.sort_values(by=['TeamLaunch']).head(15)
olddf = olddf[olddf['Tournament']> 50]
olddf.sort_values(by=['WinPercentage'], ascending=False).head(10)
# Out:
#       Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0   Team 1          86   4385         2762      1647         552        563
# 1   Team 2          86   4262         2762      1581         573        608
# 2   Team 3          80   3442         2614      1241         598        775
# 3   Team 4          82   3386         2664      1187         616        861
# 4   Team 5          86   3368         2762      1209         633        920
# 5   Team 6          73   2819         2408       990         531        887
# 7   Team 8          70   2573         2302       864         577        861
# 6   Team 7          82   2792         2626       948         608       1070
# 9  Team 10          51   1884         1728       606         440        682
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up TeamLaunch  \
# 0          5947         3140                  33         23       1929
# 1          5900         3114                  25         25       1929
# 2          4534         3309                  10          8       1929
# 3          4398         3469                   6          6   1931to32
# 4          4631         3700                   8          7       1929
# 5          3680         3373                   1          4    1934-35
# 7          3228         3230                   2          3       1929
# 6          3609         3889                   0          0       1929
# 9          2159         2492                   1          0    1932-33
#
#    HighestPositionHeld  LaunchYear TeamName  WinPercentage  defenceFactor
# 0                    1        1929        1      59.630702       1.136857
# 1                    1        1929        2      57.241130       1.127444
# 2                    1        1929        3      47.475134       1.265876
# 3                    1        1931        4      44.557057       1.302177
# 4                    1        1929        5      43.772629       1.339609
# 5                    1        1934        6      41.112957       1.400748
# 7                    1        1929        8      37.532580       1.403128
# 6                    3        1929        7      36.100533       1.480960
# 9                    1        1932       10      35.069444       1.442130

# %%
olddf.sort_values(by=['defenceFactor']).head(10)
# Out:
#       Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 1   Team 2          86   4262         2762      1581         573        608
# 0   Team 1          86   4385         2762      1647         552        563
# 2   Team 3          80   3442         2614      1241         598        775
# 3   Team 4          82   3386         2664      1187         616        861
# 4   Team 5          86   3368         2762      1209         633        920
# 5   Team 6          73   2819         2408       990         531        887
# 7   Team 8          70   2573         2302       864         577        861
# 9  Team 10          51   1884         1728       606         440        682
# 6   Team 7          82   2792         2626       948         608       1070
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up TeamLaunch  \
# 1          5900         3114                  25         25       1929
# 0          5947         3140                  33         23       1929
# 2          4534         3309                  10          8       1929
# 3          4398         3469                   6          6   1931to32
# 4          4631         3700                   8          7       1929
# 5          3680         3373                   1          4    1934-35
# 7          3228         3230                   2          3       1929
# 9          2159         2492                   1          0    1932-33
# 6          3609         3889                   0          0       1929
#
#    HighestPositionHeld  LaunchYear TeamName  WinPercentage  defenceFactor
# 1                    1        1929        2      57.241130       1.127444
# 0                    1        1929        1      59.630702       1.136857
# 2                    1        1929        3      47.475134       1.265876
# 3                    1        1931        4      44.557057       1.302177
# 4                    1        1929        5      43.772629       1.339609
# 5                    1        1934        6      41.112957       1.400748
# 7                    1        1929        8      37.532580       1.403128
# 9                    1        1932       10      35.069444       1.442130
# 6                    3        1929        7      36.100533       1.480960

# %% [markdown]
# ### Top 10 Oldest teams who played more than 50 tournaments are performing well. Almost all of the following won the tournament atleast once except Team 7. Considering the 82 tournaments played, Team 7 never reached final and their win% is also on lower side. Defence factor of Team 7 is also the lowest amongst the top 10 old teams who have played more than 50 tournaments and seems worst performing team amongst that group

# %%
mydf['BasketScored']-mydf['Score']
# Out:
# 0     1562
# 1     1638
# 2     1092
# 3     1012
# 4     1263
# 5      861
# 6      817
# 7      655
# 8      574
# 9      275
# 10     238
# 11     489
# 12     296
# 13     427
# 14     364
# 15     149
# 16     107
# 17     468
# 18      34
# 19     327
# 20     -78
# 21     152
# 22      98
# 23     144
# 24     -33
# 25     178
# 26     109
# 27     162
# 28      37
# 29      14
# 30      47
# 31     139
# 32      50
# 33      -2
# 34     134
# 35      43
# 36       2
# 37      55
# 38       9
# 39      14
# 40      48
# 41      15
# 42       7
# 43       7
# 44     120
# 45       5
# 46      90
# 47     -21
# 48     -11
# 49      69
# 50      50
# 51      97
# 52      19
# 53      55
# 54      30
# 55       1
# 56       4
# 57      15
# 58      32
# 59      20
# dtype: int32

# %% [markdown]
# ### Dataset looks faulty as it says DrawnGames. Basketball games can't be drawn.

# %% [markdown]
# ### Looking at data, it seems data is faulty. Logically score should be higher than the baskets scored. But from following analysis it seems for few teams data is faulty where Basket scored are more than the score itself

# %% [markdown]
# ### Team launch year could have been restricted to one year other than dividing between 2 like (1930-1931).

# %% [markdown]
# ### Data types of  all attributes were wrong except for Team and TeamLaunch. It should have been numeric for other attributes.
